# %% [markdown]
# # Домашнее задание 2. Преобразование данных

# %% [markdown]
# Цель этого задания -- преобразовать имеющиеся атрибуты пользователей в признаки так, чтобы полученная матрица признаков была пригодна для подачи в алгоритм кластеризации. Этап конструирования признаков -- самый важный и обычно самый долгий. К нему возвращаются много раз на протяжении решения задачи анализа данных.
#
# Кроме библиотек, использованных в первом задании, нам понадобятся следующие библиотеки:
# 1. [scikit-learn](http://scikit-learn.org/stable/) -- библиотека, реализующая множество алгоритмов машинного обучения и сопутствующих алгоритмов

# %%
import pandas as pd
import numpy as np
import pylab as pl
import sklearn.preprocessing as sp
import csv
import re
import dateutil
import math

np.set_printoptions(linewidth=150, precision=3, suppress=True)

# Plotting config
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ts_parser = lambda date_str: dateutil.parser.parse(date_str) if pd.notnull(date_str) else None
df_users = pd.read_csv("../files/hw1_out.csv", sep="\t", encoding="utf-8", quoting=csv.QUOTE_NONNUMERIC, converters={"created_at": ts_parser})
# Remove rows with users not found
df_users = df_users[pd.notnull(df_users['name'])]
df_users["lat"].fillna(value=0, inplace=True)
df_users["lon"].fillna(value=0, inplace=True)
print (df_users)
# Out:
#          user_id  class                  name      screen_name  \
# 0      984121344      0        Ramona Flowers      ciarradical
# 1      601849857      0        Akanksha Singh     Akankshayein
# 2      351429761      0       Carolina Garcia    latinaaboooty
# 3     2792643764      0           Nalrashed04      nalrashed04
# 4      215056389      0      Brigid Stinehart       Digginit95
# 5      248807431      1               Damon B      Karma2rings
# 6       61931528      0                Semaj.      _MisfitTony
# 7     2513463980      1                 junt'         jr_sims_
# 8      102137866      1        Trevor Housten     eSportsTorcH
# 9      298385420      1           Topher Loy        FeaRToPHeR
# 10     265519119      1                   :^)       toukakishi
# 11     391413781      0            Sara Marie    DandiLyon1296
# 12    2962522134      0          Landa_taylor        eulanda87
# 13    1683980311      0                  Kay        _kaykillem
# 14     103055384      1                  Sace    Lineage2_Sace
# 15     314966047      1          This dude...   HaryoWikantomo
# 16     304021536      1        Carlos Hurtado     SimDevCarlos
# 17     549781537      1            Scott Caan      WrathOfCaan
# 18      26017826      1              Cenarius      wowCenarius
# 19      23068708      1          Michael Shaw    MrMichaelShaw
# 20    2954690598      0    Stephanie Cristina   stephcristinaa
# 21     262111271      1              CoriSIMS      IamCoriSims
# 22      33423401      1           Bryce Bates       MachineUSA
# 23      14188586      0               Shannon           shasal
# 24     526024747      0                   Em✨    emilyrivera96
# 25     358842416      1        Steve Hartland         EP_Mohog
# 26     635171054      0           miss canada   celestexnoelle
# 27    1245380660      0         J.Mac On Keys     JayDeElement
# 28      19464245      1              Rachybop         rachybop
# 29         32823      1           Glenda Sims        goodwitch
# ...          ...    ...                   ...              ...
# 7969    50552332      0              Bridge♒️         BBMenace
# 7970   100545610      0                 L I Z     aestheticliz
# 7971   326666423      0  Omẳr Dâlnuurshë( ☆_☆     djdalnuurshe
# 7972    48149584      1  Melissa Jammer Lammy        _meridian
# 7973   331232337      1            tramayne     iamtramayne_
# 7974  2792895331      0                ~abby~    AbbyWehrman42
# 7975  1153119318      0         Marc Coachman       m_coachman
# 7976   260196537      0           Roy Fillyaw       royfillyaw
# 7977   140391512      1             Manaflask        Manaflask
# 7978   272708699      1           Matt T Wood        matttwood
# 7979   221394012      1               IMFenix         IM_Fenix
# 7980   122664029      0                 baker      lovesmangos
# 7981   281687136      0               UWO SSS           UWOSSS
# 7982   345191522      1                 Blunt     _BlizzardMan
# 7983  2973643876      0                   K80         hecht_ic
# 7984  2265330789      1      ASSASSINS CREED1     AssassCREED1
# 7985   172400145      0           Lee Carlson       soundaveny
# 7987   762936188      0                   IG.        Missyy___
# 7988   272610415      1                   tes           tesni4
# 7989   566277232      1            SC2Improve      SC2_Improve
# 7990  2734830705      1            Jay watson   CallOfDuty_PSN
# 7991   312358002      0         Megan Selzler      smegan_jean
# 7992  2269787251      1       Ubisoft Support  UbisoftSoupport
# 7993    15971444      1          Parvez Lakha      parvezlakha
# 7994   121975925      0     Anthony Rome Jr.      TheRealTRome
# 7995  2707928185      1        Jake Greenland       jakebender
# 7996  2181056703      0            Baby Girl        Ashp3_1130
# 7997  1654633596      0             g-swizzle     gabsthehuman
# 7998   351384703      1            Aaron Ryan   AaronAkaJergin
# 7999  2937795712      0                 (air)      probablyair
#
#                                             description verified  \
# 0     ☯Ciarra m.j.☯ |XV | religion free | music is m...    False
# 1     A big foodie who loves travelling, writing & r...    False
# 2                                                   NaN    False
# 3                  VINE:Nalrashed INSTAGRAM:Nalrashed68    False
# 4     My fashion sense is a little whack and my frie...    False
# 5     2x Call of Duty World Champion, MLG, 3x UMG, E...    False
# 6                                                 #NCAT    False
# 7                                                   NaN    False
# 8     Blizzard Associate eSports Manager. My tweets ...    False
# 9     • @MLG Pro Circuit player for -FeaR HaZe-     ...    False
# 10    mari/mars ✽ lvl 21 mage ✽ agender ✽ they/them ...    False
# 11    RH parent,elearning,yoga,turbojam, thoughtful ...    False
# 12    you never know how strong you are until being ...    False
# 13    Follow @theasiianbeauty iG : theblasianbeauty ...    False
# 14                         Lineage II Community Manager    False
# 15    ❦ | Jesus | Spedjita '14 | SMMYk -Violin | Tru...    False
# 16    I am a Gameplay Engineer for Sims 3. Represent...    False
# 17    Part of a lineage of tiny and powerful men thr...    False
# 18    Tracking the server status and world events fo...    False
# 19    Journalist now doing educational tech things. ...    False
# 20                                     professional egg    False
# 21    Pop/R&B Artist/Actor @SkysTheLimitET | MGR: @T...     True
# 22    Former EG Starcraft 2 Progamer, Work for GoodG...    False
# 23                     Little Librarian in the Big City    False
# 24                                                  NaN    False
# 25                                                  NaN    False
# 26                                       elco insomniac    False
# 27                                                  NaN    False
# 28    Hi guys, Rachybop here!\nI make videos on YouT...    False
# 29               the Goodwitch (and yet, still a witch)    False
# ...                                                 ...      ...
# 7969                                 Just keep swimming    False
# 7970                         19/ stay blessed my friend    False
# 7971        YETTT am Dj DalNuurShe  welcme all asxaabta    False
# 7972  Haiii. I'm as big as an Alakazam & Malamar! ♊️...    False
# 7973                            in a perfect world. . .    False
# 7974                               jeremy find ur chill    False
# 7975                                                NaN    False
# 7976                                                NaN    False
# 7977  Manaflask is an official Blizzard Fansite, bri...    False
# 7978  I'm a game/level designer and coder @ Valve. I...    False
# 7979  StarCraft II Progamer & Entrepreneur / Jian Ca...    False
# 7980  wanna be foodie in new England with never enou...    False
# 7981  A federally funded TRiO Program, we support 30...    False
# 7982                                             ΣΑΕ ΦΑ    False
# 7983  Don't bother showing me the line, I already kn...    False
# 7984  Hi i am the commander fanscott this my #callof...    False
# 7985  LI for now, New York Bound. \n\nCraft Beer/New...    False
# 7987            Let Love Elevate Yourself to Excellence    False
# 7988                                    I Love My Dogs.    False
# 7989  An EU based tournament, practice and improveme...    False
# 7990  Abit of black ops2/black ops/ghost, abit of fi...    False
# 7991  I hope you like feminist rants cause thats kin...    False
# 7992  No affiliation with @UbisoftSupport, but we ca...    False
# 7993  Music Junkie // Sneaker Hoarder (according to ...    False
# 7994                                                NaN    False
# 7995  HEY!!!! I got a sexy youtube channel for minec...    False
# 7996                                                NaN    False
# 7997                                        legs 4 days    False
# 7998  Wisconsin | Packers | Former Professional Call...    False
# 7999                i haet my slef - Ezra Koenig (1991)    False
#
#                     location       lat        lon         country  \
# 0                    florida -33.83333  -55.91667         Uruguay
# 1                      India  22.00000   79.00000           India
# 2                        NaN   0.00000    0.00000             NaN
# 3                        NaN   0.00000    0.00000             NaN
# 4                        LFK  31.23408  -94.75021   United States
# 5           On Another Level   0.00000    0.00000             NaN
# 6                      ✌️✋✌️   0.00000    0.00000             NaN
# 7                        NaN   0.00000    0.00000             NaN
# 8                 Irvine, CA  33.66946 -117.82311   United States
# 9                 #FeaR4Life   0.00000    0.00000             NaN
# 10                     SKÜLE   0.00000    0.00000             NaN
# 11                       NaN   0.00000    0.00000             NaN
# 12                       NaN   0.00000    0.00000             NaN
# 13          Indianapolis, IN  39.76838  -86.15804   United States
# 14               Seattle, WA  47.60621 -122.33207   United States
# 15    Yogyakarta - Indonesia  -7.78278  110.36083       Indonesia
# 16        Redwood Shores, CA  37.53188 -122.24802   United States
# 17             Hollywood, CA  34.09834 -118.32674   United States
# 18                       NaN   0.00000    0.00000             NaN
# 19                    London  51.50853   -0.12574  United Kingdom
# 20                   florida  28.75054  -82.50010   United States
# 21             Calabasas, CA  34.15778 -118.63842   United States
# 22         San Francisco, CA  37.77493 -122.41942   United States
# 23           Los Angeles, CA  34.05223 -118.24368   United States
# 24                       NaN   0.00000    0.00000             NaN
# 25              Cornwall, UK  50.41667   -4.75000  United Kingdom
# 26                       NaN   0.00000    0.00000             NaN
# 27          Cape Town, Town. -33.92584   18.42322    South Africa
# 28             Yorkshire, UK  53.91667   -0.50000  United Kingdom
# 29             Austin, Texas  30.26715  -97.74306   United States
# ...                      ...       ...        ...             ...
# 7969                     NaN   0.00000    0.00000             NaN
# 7970                 find me   0.00000    0.00000             NaN
# 7971         nykoping,sweden   0.00000    0.00000             NaN
# 7972                     NaN   0.00000    0.00000             NaN
# 7973                     NaN   0.00000    0.00000             NaN
# 7974                     NaN   0.00000    0.00000             NaN
# 7975                     NaN   0.00000    0.00000             NaN
# 7976         Bloomington, IN   0.00000    0.00000             NaN
# 7977                     NaN   0.00000    0.00000             NaN
# 7978            Bellevue, WA   0.00000    0.00000             NaN
# 7979                     NaN   0.00000    0.00000             NaN
# 7980                  Boston   0.00000    0.00000             NaN
# 7981             Oshkosh, WI   0.00000    0.00000             NaN
# 7982           In the field    0.00000    0.00000             NaN
# 7983               Neverland   0.00000    0.00000             NaN
# 7984              on xbox360   0.00000    0.00000             NaN
# 7985           Mattituck, NY   0.00000    0.00000             NaN
# 7987                     NaN   0.00000    0.00000             NaN
# 7988                     NaN   0.00000    0.00000             NaN
# 7989   Leeds, United Kingdom   0.00000    0.00000             NaN
# 7990                     NaN   0.00000    0.00000             NaN
# 7991                     NaN   0.00000    0.00000             NaN
# 7992                     NaN   0.00000    0.00000             NaN
# 7993                     NYC   0.00000    0.00000             NaN
# 7994     Moorhead, Minnesota   0.00000    0.00000             NaN
# 7995                     NaN   0.00000    0.00000             NaN
# 7996                     NaN   0.00000    0.00000             NaN
# 7997                 #live95   0.00000    0.00000             NaN
# 7998                     NaN   0.00000    0.00000             NaN
# 7999        probably joking    0.00000    0.00000             NaN
#
#                      created_at  followers_count  friends_count  \
# 0     2012-12-02 07:46:25+00:00              224            529
# 1     2012-06-07 10:55:20+00:00               82            749
# 2     2011-08-09 07:11:35+00:00              469            606
# 3     2014-09-05 21:38:24+00:00               30            399
# 4     2010-11-12 22:05:53+00:00              364            508
# 5     2011-02-07 19:29:05+00:00           203374           1093
# 6     2009-08-01 01:52:06+00:00            11804           7898
# 7     2014-05-21 19:34:25+00:00              742            538
# 8     2010-01-05 19:07:10+00:00             6036            450
# 9     2011-05-14 06:54:18+00:00             3106            866
# 10    2011-03-13 17:48:07+00:00              270            302
# 11    2011-10-15 14:45:36+00:00               87            326
# 12    2015-01-07 07:39:19+00:00              117            168
# 13    2013-08-19 18:58:22+00:00              429            411
# 14    2010-01-08 18:40:33+00:00              629              3
# 15    2011-06-11 03:00:30+00:00              118            176
# 16    2011-05-23 20:07:19+00:00              452             21
# 17    2012-04-10 03:39:06+00:00             1887           1016
# 18    2009-03-23 15:08:59+00:00              280             89
# 19    2009-03-06 14:24:30+00:00             6681           1792
# 20    2015-01-01 11:32:34+00:00               65            320
# 21    2011-03-07 11:16:24+00:00             2489            691
# 22    2009-04-20 04:28:56+00:00            17260            337
# 23    2008-03-21 01:00:52+00:00               67            311
# 24    2012-03-16 04:20:17+00:00              470            370
# 25    2011-08-20 16:02:19+00:00             1944            436
# 26    2012-07-14 06:42:26+00:00              438            408
# 27    2013-03-06 06:03:33+00:00               71            199
# 28    2009-01-24 21:28:47+00:00             3790           1430
# 29    2006-11-30 19:10:28+00:00             2394            542
# ...                         ...              ...            ...
# 7969  2009-06-25 04:42:06+00:00              400            424
# 7970  2009-12-30 17:06:25+00:00              546            471
# 7971  2011-06-30 08:45:22+00:00               23             38
# 7972  2009-06-17 22:50:12+00:00              366             85
# 7973  2011-07-07 21:11:50+00:00              303            318
# 7974  2014-09-06 00:42:54+00:00              224            521
# 7975  2013-02-06 06:32:48+00:00               75            350
# 7976  2011-03-03 11:55:21+00:00              189            350
# 7977  2010-05-05 11:14:08+00:00             6916             27
# 7978  2011-03-27 01:26:34+00:00             4334            588
# 7979  2010-11-30 15:08:46+00:00             3944             88
# 7980  2010-03-13 13:19:52+00:00              121            431
# 7981  2011-04-13 19:30:32+00:00               79            161
# 7982  2011-07-30 05:48:29+00:00              495            323
# 7983  2015-01-11 19:40:57+00:00               77            204
# 7984  2014-01-06 14:36:59+00:00               80            156
# 7985  2010-07-29 16:35:03+00:00              137            304
# 7987  2012-08-17 03:53:55+00:00              121            167
# 7988  2011-03-26 20:51:54+00:00              432            360
# 7989  2012-04-29 12:59:07+00:00              963            229
# 7990  2014-08-06 07:13:24+00:00               56            337
# 7991  2011-06-07 00:34:28+00:00              418            297
# 7992  2013-12-31 03:25:23+00:00              112             48
# 7993  2008-08-24 18:46:45+00:00              942            348
# 7994  2010-03-11 05:51:52+00:00             1102            930
# 7995  2014-08-05 01:16:41+00:00             1108             41
# 7996  2013-11-14 19:10:08+00:00               68            159
# 7997  2013-08-08 05:44:33+00:00              310            381
# 7998  2011-08-09 05:15:31+00:00             5274            627
# 7999  2014-12-23 01:15:14+00:00               92            118
#
#       statuses_count  favourites_count  listed_count
# 0               5136              2984             3
# 1                924                 2             1
# 2               9500             13125             0
# 3                111               108             1
# 4                630              1749             0
# 5              67098             11744           405
# 6              19204               836            14
# 7               3050              2190             0
# 8               1710                21           160
# 9               4897               412            27
# 10             35913             27375             4
# 11               235               214             4
# 12               880                 3             0
# 13              7771               828             0
# 14                59                 0             8
# 15              2056                43             1
# 16                83                 0            23
# 17               371                20             9
# 18               583                 0             1
# 19              5148                38           203
# 20               158              2898             2
# 21             15452              2406            21
# 22              4531               374           296
# 23               312                32             2
# 24             17319              3171             0
# 25              8793             10152             5
# 26              7291              2892             2
# 27               683                17             0
# 28             16706              2495            99
# 29              8100               790           249
# ...              ...               ...           ...
# 7969            8613              3369             4
# 7970            9536              2352            24
# 7971             148                 3             0
# 7972            8007              6561             8
# 7973           18158                47             3
# 7974            1274               888             1
# 7975             895               258             0
# 7976            1473              1158             1
# 7977            2922                31            83
# 7978            1280               456            62
# 7979             384                 8            48
# 7980            8053               416             3
# 7981             405                 9             2
# 7982           15820              1461             1
# 7983             341               485             0
# 7984             203                 6             0
# 7985             692               195             0
# 7987            1967              2992             0
# 7988            2202              3075             0
# 7989            4072               550             9
# 7990              42                 9             0
# 7991            1524              4234             2
# 7992             207                56             0
# 7993           11354              1151            33
# 7994            9693               838            14
# 7995             140               272             0
# 7996            1780               272             0
# 7997            5011              6858             1
# 7998            8389               411            16
# 7999             196              1437             0
#
# [7958 rows x 16 columns]

# %% [markdown]
# Далее необходимо ввести новые признаки. Для каждого пользователя предлагается ввести следующие признаки:
# - name_words - количество слов в имени
# - screen_name_length - количество символов в псевдониме
# - description_length - длина описания
# - created_year - год создания аккаунта
# - country_code - код страны
# - verified - предлагается перевести в тип int

# %%
def create_new_features(df_users, features):
    # Introduce new features
    new_features = ["name_words", "screen_name_length", "description_length", "country_code", "created_year", "verified"] #"country_code"
    
    parse = dateutil.parser.parse
    
    cp = 0
    cd = dict()
    for i in df_users["country"]:
        if i not in cd:
            cd[i] = cp
            cp += 1
    
    # Calculate new features and place them into data frame
    df_users["name_words"] = np.array(map(lambda nm: len(nm.split()), df_users["name"]))
    df_users["screen_name_length"] = np.array(map(lambda snm: len(snm), df_users["screen_name"]))
    df_users["description_length"] = np.array(map(lambda dsc: 0 if dsc is np.nan else len(dsc), df_users["description"]))                                         
    df_users["created_year"] = np.array(map(lambda dt: dt.year, df_users["created_at"]))
    df_users["country_code"] = np.array(map(lambda cn: cd[cn], df_users["country"]))
    df_users["verified"] = np.array(map(lambda vr: int(vr), df_users["verified"]))
    
    return df_users, features + new_features

# %%
features = ["lat", "lon", "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count"]
df_users, features = create_new_features(df_users, features)

x = df_users[features].values
y = df_users["class"].values
print x
# Out:
# [[  -33.833   -55.917   224.    ...,     0.     2012.        0.   ]
#  [   22.       79.       82.    ...,     1.     2012.        0.   ]
#  [    0.        0.      469.    ...,     2.     2011.        0.   ]
#  ...,
#  [    0.        0.      310.    ...,     2.     2013.        0.   ]
#  [    0.        0.     5274.    ...,     2.     2011.        0.   ]
#  [    0.        0.       92.    ...,     2.     2014.        0.   ]]

# %% [markdown]
# Посмотрим, являются ли какие-либо из выбранных признаков сильно скоррелированными. Для этого посчитаем матрицу корреляций и выберем те пары признаков, фбсолютное значения коэффициента корреляции между которыми больше 0.2. Необходимо реализовать функцию find_correlated_features, в которой нужно рассчитать коэффициенты корелляции и вывести те, которые больше 0.2. Подсказка: предлагается найти необходимую функцию в библиотеке np и реализовать find_correlated_features с использованием не более 5 строк кода.

# %%
def find_correlated_features(x, features):
    corr_matrix = np.corrcoef(x)
    for i, feature_i in enumerate(features):
        for j, feature_j in enumerate(features):
            if i < j and abs(corr_matrix[i][j]) > 0.2:
                print "Correlated features: %s + %s -> %.2f" % (feature_i, feature_j, corr_matrix[i][j])

# %%
find_correlated_features(x, features)
# Out:
# Correlated features: lat + lon -> 0.51
# Correlated features: lat + followers_count -> 0.87
# Correlated features: lat + friends_count -> 0.27
# Correlated features: lat + statuses_count -> 0.64
# Correlated features: lat + listed_count -> 0.66
# Correlated features: lat + name_words -> 0.97
# Correlated features: lat + description_length -> 0.74
# Correlated features: lat + country_code -> 0.94
# Correlated features: lat + created_year -> 0.34
# Correlated features: lat + verified -> 0.53
# Correlated features: lon + friends_count -> 0.92
# Correlated features: lon + statuses_count -> 0.69
# Correlated features: lon + listed_count -> 0.37
# Correlated features: lon + name_words -> 0.62
# Correlated features: lon + screen_name_length -> 0.26
# Correlated features: lon + description_length -> 0.54
# Correlated features: lon + country_code -> 0.20
# Correlated features: lon + created_year -> 0.92
# Correlated features: lon + verified -> 0.96
# Correlated features: followers_count + statuses_count -> 0.65
# Correlated features: followers_count + listed_count -> 0.41
# Correlated features: followers_count + name_words -> 0.85
# Correlated features: followers_count + description_length -> 0.45
# Correlated features: followers_count + country_code -> 0.94
# Correlated features: followers_count + verified -> 0.20
# Correlated features: friends_count + statuses_count -> 0.74
# Correlated features: friends_count + name_words -> 0.44
# Correlated features: friends_count + screen_name_length -> 0.21
# Correlated features: friends_count + description_length -> 0.26
# Correlated features: friends_count + created_year -> 0.99
# Correlated features: friends_count + verified -> 0.92
# Correlated features: statuses_count + name_words -> 0.78
# Correlated features: statuses_count + screen_name_length -> 0.24
# Correlated features: statuses_count + description_length -> 0.37
# Correlated features: statuses_count + country_code -> 0.48
# Correlated features: statuses_count + created_year -> 0.78
# Correlated features: statuses_count + verified -> 0.70
# Correlated features: favourites_count + listed_count -> 0.67
# Correlated features: favourites_count + name_words -> 0.27
# Correlated features: favourites_count + screen_name_length -> 0.94
# Correlated features: favourites_count + description_length -> 0.67
# Correlated features: listed_count + name_words -> 0.65
# Correlated features: listed_count + screen_name_length -> 0.63
# Correlated features: listed_count + description_length -> 0.94
# Correlated features: listed_count + country_code -> 0.59
# Correlated features: listed_count + verified -> 0.31
# Correlated features: name_words + screen_name_length -> 0.33
# Correlated features: name_words + description_length -> 0.77
# Correlated features: name_words + country_code -> 0.86
# Correlated features: name_words + created_year -> 0.50
# Correlated features: name_words + verified -> 0.64
# Correlated features: screen_name_length + description_length -> 0.71
# Correlated features: screen_name_length + created_year -> 0.24
# Correlated features: screen_name_length + verified -> 0.31
# Correlated features: description_length + country_code -> 0.61
# Correlated features: description_length + created_year -> 0.31
# Correlated features: description_length + verified -> 0.55
# Correlated features: country_code + verified -> 0.23
# Correlated features: created_year + verified -> 0.94

# %% [markdown]
# Выделилось 3 группы признаков:
# 1. Основанные на географии:  "lat", "lon", "country_code"
# 2. Основанные на социальной активности:  "verified", "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count", "created_year"
# 3. Остальные:  "name_words", "screen_name_length", "description_length"
#
# Построим взаимные распределения пар признаков в каждой из групп, а также гистограмму значений каждого из признаков с учетом целевой переменной.

# %% [markdown]
# Необходимо реализовать функции: plot_two_features_scatter для построения взаимного распределения пары признаков, plot_feature_histogram для построения гистограммы значений, plot_dataset для построения набора графиков по разным парам признаков.

# %%
def plot_two_features_scatter(ax, x_i, x_j, y):
    x_i = x_i - min(x_i)
    x_i = x_i / max(x_i)
    x_j = x_j - min(x_j)
    x_j = x_j / max(x_j)
    
    cl = ["red" if cls else "green" for cls in y]

    ax.scatter(x_j, x_i, s=20, marker='.', c=cl, linewidth=0)
    
    ax.set_xlim((-0.1, 1.1)) #чуть-чуть сместим картинку в центер, чтобы края не мешали
    ax.set_ylim((-0.1, 1.1)) 
    ax.set_xticks([-0.1 + 0.1 * i for i in range(1, 13)])
    ax.set_xticklabels([""]*12)
    ax.set_yticks([0.1 * i for i in range(1, 13)])
    ax.set_yticklabels([""]*12)
    
def plot_feature_histogram(ax, x_i, y):
    x_i = x_i - min(x_i)
    x_i = x_i / max(x_i)
    size = len(x_i)
    hist = [[0]*2 for i in range(10)]
    
    for i, val in enumerate(x_i):
        hid = int((val - 1e-3) * 10)
        hist[hid][0] += y[i]
        hist[hid][1] += 1 - y[i]
    
    lft, h, w, cl = list(), list(), list(), list() 
    for i, val in enumerate(hist):
        lft += [i*0.1, i*0.1 + 0.05]
        h += [float(hist[i][0])/size + 1e-3, float(hist[i][1])/size + 1e-3]
        w += [0.05, 0.05]
        cl += ["red", "green"]

    ax.bar(lft, h, width=w, color=cl)
    ax.set_xlim((0, 1))
    ax.set_ylim((0, 1))
    ax.set_xticks([0.1 * i for i in range(1, 11)])
    ax.set_xticklabels([""]*10)
    ax.set_yticks([0.1 * i for i in range(1, 11)])
    ax.set_yticklabels([""]*10)
    
        

def plot_dataset(x, y, features):
    print x
    fig, ax = pl.subplots(len(features), len(features), squeeze=True)
    fig.set_size_inches((len(features)*3, len(features)*3))
    for i, feature_i in enumerate(features):
        for j, feature_j in enumerate(features):
            
            if j == 0:
                ax[i][j].set_ylabel(feature_i)
            if i == 0:
                ax[i][j].set_title(feature_j)
            
            # Do actual plotting
            if i != j:
                plot_two_features_scatter(ax[i][j], x[:, i], x[:, j], y)            
            else:
                plot_feature_histogram(ax[i][j], x[:, i], y)
    
    pl.show()

# %% [markdown]
# Построим попарные распределения географических признаков ([подсказка](http://anokhin.github.io/img/hw2_geo.png)).

# %%
geo_features_new = ["lat", "lon", "country_code"]
geo_features = [f for f in features if f in geo_features_new]

geo_feature_ind = [i for i, f in enumerate(features) if f in geo_features]
print geo_features
plot_dataset(x[:, geo_feature_ind], y, geo_features)
# Out:
# ['lat', 'lon', 'country_code']
# [[-33.833 -55.917   0.   ]
#  [ 22.     79.      1.   ]
#  [  0.      0.      2.   ]
#  ...,
#  [  0.      0.      2.   ]
#  [  0.      0.      2.   ]
#  [  0.      0.      2.   ]]

# %% [markdown]
# Четко видны очертания карты и то, что большинство пользователей происходят из небольшого набора стран. Если принять во внимание конечную цель -- кластеризацию пользователей -- логично предположить, что использование географических признаков для описания пользователя может оказаться не очень полезным. Причина в том, что эти признаки четко пространственно разделены (как минимум, океанами и морями). Поэтому мы рискуем вместо "интересной" кластеризации получить просто кластеры, которые будут представлять разные страны. В дальнейшем мы исключим географические признаки из рассмотрения при кластеризации пользователей.
#
# Далее построим попарные распределения социальных признаков ([подсказка](http://anokhin.github.io/img/hw2_social1.png)).

# %%
social_features_new = ["verified", "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count", "created_year"]
social_features = [f for f in features if f in social_features_new]
social_feature_ind = [i for i, f in enumerate(features) if f in social_features]
plot_dataset(x[:, social_feature_ind], y, social_features)
# Out:
# [[  224.   529.  5136. ...,     3.  2012.     0.]
#  [   82.   749.   924. ...,     1.  2012.     0.]
#  [  469.   606.  9500. ...,     0.  2011.     0.]
#  ...,
#  [  310.   381.  5011. ...,     1.  2013.     0.]
#  [ 5274.   627.  8389. ...,    16.  2011.     0.]
#  [   92.   118.   196. ...,     0.  2014.     0.]]

# %% [markdown]
# Из графиков видно, что признаки "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count" сильно смещены в сторону небольших значений. В таком случае удобно сделать логарифмическое преобразрвание этих признаков, то есть применить к их значениям $x_{ij}$ функцию $\log(1 + x_{ij})$. Сделаем это и построим новые распределения ([подсказка](http://anokhin.github.io/img/hw2_social2.png)). Необходимо реализовать функцию log_transform_features, которая выполняет указанное логарифмическое преобразование.

# %%
def log_transform_features(data, features, transformed_features):
    for row_i, row in enumerate(data):
        for j, el in enumerate(row):
            if features[j] in transformed_features:
                data[row_i][j] = np.log(el + 1)
    return data

# %%
transformed_features = ["followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count"]
x = log_transform_features(x, features, transformed_features)

# Re-plot features
plot_dataset(x[:, social_feature_ind], y, social_features)
# Out:
# [[    5.416     6.273     8.544 ...,     1.386  2012.        0.   ]
#  [    4.419     6.62      6.83  ...,     0.693  2012.        0.   ]
#  [    6.153     6.409     9.159 ...,     0.     2011.        0.   ]
#  ...,
#  [    5.74      5.945     8.52  ...,     0.693  2013.        0.   ]
#  [    8.571     6.443     9.035 ...,     2.833  2011.        0.   ]
#  [    4.533     4.779     5.283 ...,     0.     2014.        0.   ]]

# %% [markdown]
# Сразу бросается в глаза, что признак "verified" сильно смещен -- верифицированных пользователей очень мало. Более того, все верифицированные пользователи имеют много фолловеров, поэтому часть информации о верификации дублируется в признаке "followers_count". По этой причине в дальнейшем не будем рассмтаривать признак "verified".
#
# После того как мы с помощью логарифмического преобразования избавились от сильной скошенности признаков, можно наблюдать некоторые интересные зависимости. Например, пользователи, имеющие много фолловеров, обязательно имеют много статусов. Следовательно, чтобы стать популярным, обязательно нужно много писать. Анализ других зависимостей остается как упражнение.
#
# Наконец построим попарные распределения остальных признаков ([подсказка](http://anokhin.github.io/img/hw2_other.png)).

# %%
other_features_new = ["name_words", "screen_name_length", "description_length"]
other_features = [f for f in other_features_new if f in features]
other_feature_ind = [i for i, f in enumerate(features) if f in other_features]
plot_dataset(x[:, other_feature_ind], y, other_features)
# Out:
# [[   2.   11.   92.]
#  [   2.   12.  110.]
#  [   2.   13.    0.]
#  ...,
#  [   1.   12.   11.]
#  [   2.   14.  131.]
#  [   1.   11.   35.]]

# %% [markdown]
# Итак после первичной обработки данных мы имеем 9 числовых признаков, каждый из которых распределен в некотором своем интервале. Для того, чтобы ни один признак не получил перевеса при кластеризации, нормализуем данные так, что каждый признак распределен на отрезке $[0, 1]$.

# %%
selected_features = ["followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count", "created_year", "name_words", "screen_name_length", "description_length"]
selected_features_ind = [i for i, f in enumerate(features) if f in selected_features]

x_1 = x[:, selected_features_ind]

# Replace nan with 0-s
# Is there a smarter way?
x_1[np.isnan(x_1)] = 0
x_min = x_1.min(axis=0)
x_max = x_1.max(axis=0)
x_new = (x_1 - x_min) / (x_max - x_min)

# %% [markdown]
# Упакуем полученную матрицу в pandas DataFrame и сохраним в файл "hw2_out.csv". В следующем задании мы будем кластеризовать пользователей на оновании этих данных.

# %%
df_out = pd.DataFrame(data=x_new, index=df_users["user_id"], columns=[f for f in selected_features])
df_out.to_csv("../files/hw2_out.csv", sep="\t")
